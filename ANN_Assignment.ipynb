# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### GENDER : M [Male] , F [Female]
# #### AGE : Age of patients
# #### SMOKING : 2 [Yes] , 1 [No]
# #### YELLOW_FINGERS : 2 [Yes] , 1 [No]
# ####ANXIETY :2 [Yes] , 1 [No] PEER_PRESSURE : 2 [Yes] , 1 [No]
# ####CHRONIC DISEASE : 2 [Yes] , 1 [No]
# ####FATIGUE : 2 [Yes] , 1 [No]
# ####ALLERGY : 2 [Yes] , 1 [No]
# ####WHEEZING : 2 [Yes] , 1 [No]
# ####ALCOHOL CONSUMING : 2 [Yes] , 1 [No]
# ####COUGHING : 2 [Yes] , 1 [No]
# ####SHORTNESS OF BREATH : 2 [Yes] , 1 [No]
# ####SWALLOWING DIFFICULTY : 2 [Yes] , 1 [No]
# ####CHEST PAIN : 2 [Yes] , 1 [No]
# ####LUNG_CANCER : YES [Positive] , NO [Negative]

# %%
data = pd.read_csv("survey lung cancer.csv")

# %%
print(f"Shape of The Dataset : {data.shape}")
print(f"\nGlimpse of The Dataset :")
data.head()
# Out:
# Shape of The Dataset : (309, 16)
#
# Glimpse of The Dataset :
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
print(f"Informations About The Dataset :\n")
print(data.info())
# Out:
# Informations About The Dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 38.8+ KB
# None

# %%
print(f"Summary of This Dataset :")
data.describe()
# Out:
# Summary of This Dataset :
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       309.000000  309.000000  309.000000  309.000000         309.000000
# mean          1.504854    1.673139    1.556634    1.556634           1.556634
# std           0.500787    0.469827    0.497588    0.497588           0.497588
# min           1.000000    1.000000    1.000000    1.000000           1.000000
# 25%           1.000000    1.000000    1.000000    1.000000           1.000000
# 50%           2.000000    2.000000    2.000000    2.000000           2.000000
# 75%           2.000000    2.000000    2.000000    2.000000           2.000000
# max           2.000000    2.000000    2.000000    2.000000           2.000000
#
#          COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN
# count  309.000000           309.000000             309.000000  309.000000
# mean     1.579288             1.640777               1.469256    1.556634
# std      0.494474             0.480551               0.499863    0.497588
# min      1.000000             1.000000               1.000000    1.000000
# 25%      1.000000             1.000000               1.000000    1.000000
# 50%      2.000000             2.000000               1.000000    2.000000
# 75%      2.000000             2.000000               2.000000    2.000000
# max      2.000000             2.000000               2.000000    2.000000

# %%
data.describe(include=object)
# Out:
#        GENDER LUNG_CANCER
# count     309         309
# unique      2           2
# top         M         YES
# freq      162         270

# %%
data.isna().sum().to_frame()
# Out:
#                        0
# GENDER                 0
# AGE                    0
# SMOKING                0
# YELLOW_FINGERS         0
# ANXIETY                0
# PEER_PRESSURE          0
# CHRONIC DISEASE        0
# FATIGUE                0
# ALLERGY                0
# WHEEZING               0
# ALCOHOL CONSUMING      0
# COUGHING               0
# SHORTNESS OF BREATH    0
# SWALLOWING DIFFICULTY  0
# CHEST PAIN             0
# LUNG_CANCER            0

# %% [markdown]
# ####Here, we can see there is no null value exists in this dataset. Let's check if there exists any duplicate entry in this dataset. If exists then we will remove them from the dataset. After that we will initialize the visualization style and custom pallete for visualization.

# %%
dup = data[data.duplicated()].shape[0]
print(f"There are {dup} duplicate entries among {data.shape[0]} entries in this dataset.")

data.drop_duplicates(keep='first',inplace=True)
print(f"\nAfter removing duplicate entries there are {data.shape[0]} entries in this dataset.")
# Out:
# There are 33 duplicate entries among 309 entries in this dataset.
#
# After removing duplicate entries there are 276 entries in this dataset.

# %%
data_temp = data.copy()
data_temp["GENDER"] = data_temp["GENDER"].replace({"M" : "Male" , "F" : "Female"})

for column in data_temp.columns:
    data_temp[column] = data_temp[column].replace({2: "Yes" , 1 : "No"})

data_temp.head()
# Out:
#    GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0    Male   69      No            Yes     Yes            No              No
# 1    Male   74     Yes             No      No            No             Yes
# 2  Female   59      No             No      No           Yes              No
# 3    Male   63     Yes            Yes     Yes            No              No
# 4  Female   63      No            Yes      No            No              No
#
#   FATIGUE  ALLERGY  WHEEZING ALCOHOL CONSUMING COUGHING SHORTNESS OF BREATH  \
# 0      Yes       No      Yes               Yes      Yes                 Yes
# 1      Yes      Yes       No                No       No                 Yes
# 2      Yes       No      Yes                No      Yes                 Yes
# 3       No       No       No               Yes       No                  No
# 4       No       No      Yes                No      Yes                 Yes
#
#   SWALLOWING DIFFICULTY CHEST PAIN LUNG_CANCER
# 0                   Yes        Yes         YES
# 1                   Yes        Yes         YES
# 2                    No        Yes          NO
# 3                   Yes        Yes          NO
# 4                    No         No          NO

# %% [markdown]
# ###Custom Palette For Visualization

# %%
sns.set_style("whitegrid")
sns.set_context("poster",font_scale = .7)

palette = ["#1d7874","#679289","#f4c095","#ee2e31","#ffb563","#918450","#f85e00","#a41623","#9a031e","#d6d6d6","#ffee32","#ffd100","#333533","#202020"]

# sns.palplot(sns.color_palette(palette))
# plt.show()

# %% [markdown]
# ###Positive Lung Cancer Cases

# %% [markdown]
# ###Let's create a new dataframe containing only positive cases data.

# %%
data_temp_pos = data_temp[data_temp["LUNG_CANCER"] == "YES"]
data_temp_pos.head()
# Out:
#    GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC DISEASE  \
# 0    Male   69      No            Yes     Yes            No              No
# 1    Male   74     Yes             No      No            No             Yes
# 5  Female   75      No            Yes      No            No             Yes
# 6    Male   52     Yes             No      No            No              No
# 7  Female   51     Yes            Yes     Yes           Yes              No
#
#   FATIGUE  ALLERGY  WHEEZING ALCOHOL CONSUMING COUGHING SHORTNESS OF BREATH  \
# 0      Yes       No      Yes               Yes      Yes                 Yes
# 1      Yes      Yes       No                No       No                 Yes
# 5      Yes      Yes      Yes                No      Yes                 Yes
# 6      Yes       No      Yes               Yes      Yes                 Yes
# 7      Yes      Yes       No                No       No                 Yes
#
#   SWALLOWING DIFFICULTY CHEST PAIN LUNG_CANCER
# 0                   Yes        Yes         YES
# 1                   Yes        Yes         YES
# 5                    No         No         YES
# 6                    No        Yes         YES
# 7                   Yes         No         YES

# %% [markdown]
# ##Positive Cases' Age Distribution

# %%
_, axs = plt.subplots(2,1,figsize=(20,10),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

sns.histplot(data_temp_pos[data_temp_pos["GENDER"]=="Male"]["AGE"],color=palette[11],kde=True,ax=axs[0],bins=20,alpha=1,fill=True)
axs[0].lines[0].set_color(palette[12])
axs[0].set_title("\nPositive Male Cases Age Distribution\n",fontsize=20)
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Quantity")

sns.histplot(data_temp_pos[data_temp_pos["GENDER"]=="Female"]["AGE"],color=palette[12],kde=True,ax=axs[1],bins=20,alpha=1,fill=True)
axs[1].lines[0].set_color(palette[11])
axs[1].set_title("\nPositive Female Cases Age Distribution\n",fontsize=20)
axs[1].set_xlabel("Age")
axs[1].set_ylabel("Quantity")

sns.despine(left=True, bottom=True)
plt.show()

# %%
plt.subplots(figsize=(20, 8))
p = sns.histplot(data=data_temp_pos,x="AGE",hue="GENDER",multiple="stack",palette=palette[11:13],kde=True,shrink=.99,bins=20,alpha=1,fill=True)
p.axes.lines[0].set_color(palette[11])
p.axes.lines[1].set_color(palette[12])
p.axes.set_title("\nPositive Cases Age Distribution\n",fontsize=20)
plt.ylabel("Count")
plt.xlabel("Age")

sns.despine(left=True, bottom=True)
plt.show()

# %%
plt.subplots(figsize=(12, 12))

labels = "Male","Female"
size = 0.5

wedges, texts, autotexts = plt.pie([len(data_temp_pos[data_temp_pos["GENDER"]=="Male"]["GENDER"]),
                                    len(data_temp_pos[data_temp_pos["GENDER"]=="Female"]["GENDER"])],
                                    explode = (0,0),
                                    textprops=dict(size= 25, color= "white"),
                                    autopct="%.2f%%",
                                    pctdistance = 0.7,
                                    radius=.9,
                                    colors = ["#0f4c5c","#FFC300"],
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "white",
                                    linewidth = 5),
                                    startangle = 0)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.title("\nPositive Cases' Gender Distribution",fontsize=20)
plt.show()

# %% [markdown]
# ##Gender-wise Positive Cases' Reasons

# %%
_, axs = plt.subplots(1,2,figsize=(15,8),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SMOKING",hue_order=["Yes","No"],ax=axs[0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0].set_title("\nEffect of Smoking\n",fontsize=20)
axs[0].set_xlabel("Gender")
axs[0].set_ylabel("Quantity")
for container in axs[0].containers:
    axs[0].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="ALCOHOL CONSUMING",hue_order=["Yes","No"],ax=axs[1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1].set_title("\nEffect of Alcohol Consuming\n",fontsize=20)
axs[1].set_xlabel("Gender")
axs[1].set_ylabel("Quantity")
for container in axs[1].containers:
    axs[1].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ###Gender-wise Positive Cases' Symptoms

# %%
_, axs = plt.subplots(2,5,figsize=(20,14),sharex=False,sharey=True)
plt.tight_layout(pad=4.0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="YELLOW_FINGERS",hue_order=["Yes","No"],ax=axs[0,0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,0].set_ylabel("Total")
axs[0,0].legend(title="Yellow Fingers",loc="upper left")


sns.countplot(data=data_temp_pos,x="GENDER",hue="ANXIETY",hue_order=["Yes","No"],ax=axs[0,1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,1].set_ylabel("Total")
axs[0,1].legend(title="Anxiety",loc="upper right")
for container in axs[0,1].containers:
    axs[0,1].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="CHRONIC DISEASE",hue_order=["Yes","No"],ax=axs[0,2],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,2].set_ylabel("Total")
axs[0,2].legend(title="Chronic Disease",loc="upper right")
for container in axs[0,2].containers:
    axs[0,2].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="CHEST PAIN",hue_order=["Yes","No"],ax=axs[0,3],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,3].set_ylabel("Total")
axs[0,3].legend(title="Chest Pain",loc="upper right")
for container in axs[0,3].containers:
    axs[0,3].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="FATIGUE ",hue_order=["Yes","No"],ax=axs[0,4],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,4].set_ylabel("Total")
axs[0,4].legend(title="Fatigue",loc="upper right")
for container in axs[0,4].containers:
    axs[0,4].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="WHEEZING",hue_order=["Yes","No"],ax=axs[1,0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,0].set_ylabel("Total")
axs[1,0].legend(title="Wheezing",loc="upper right")
for container in axs[1,0].containers:
    axs[1,0].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="COUGHING",hue_order=["Yes","No"],ax=axs[1,1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,1].set_ylabel("Total")
axs[1,1].legend(title="Coughing",loc="upper right")
for container in axs[1,1].containers:
    axs[1,1].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SHORTNESS OF BREATH",hue_order=["Yes","No"],ax=axs[1,2],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,2].set_ylabel("Total")
axs[1,2].legend(title="Short Breath",loc="upper right")
for container in axs[1,2].containers:
    axs[1,2].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SWALLOWING DIFFICULTY",hue_order=["Yes","No"],ax=axs[1,3],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,3].set_ylabel("Total")
axs[1,3].legend(title="Swallowing Difficulty",loc="upper right")
for container in axs[1,3].containers:
    axs[1,3].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="ALLERGY ",hue_order=["Yes","No"],ax=axs[1,4],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,4].set_ylabel("Total")
axs[1,4].legend(title="Allergy",loc="upper right")
for container in axs[1,4].containers:
    axs[1,4].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ##Correlation Heatmap

# %% [markdown]
# ####Converting the target feature "LUNG_CANCER" from Categorical to Numerical data type by using Label Encoder. And converting the "GENDER" column from Categorical to Numerical data type by using "One Hot Encoder" for avoiding unexpected gender bias.

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder = LabelEncoder()

data["GENDER"] = data["GENDER"].replace({"M" : "Male" , "F" : "Female"})
data["LUNG_CANCER"] = LabelEncoder.fit_transform(data["LUNG_CANCER"])

data = pd.get_dummies(data, columns= ["GENDER"])
data.rename(columns={"GENDER_Male" : "MALE", "GENDER_Female" : "FEMALE", "YELLOW_FINGERS" : "YELLOW FINGERS", "PEER_PRESSURE" : "PEER PRESSURE", "LUNG_CANCER" : "LUNG CANCER", "FATIGUE " : "FATIGUE", "ALLERGY " : "ALLERGY"}, inplace=True)
data = data[["AGE","MALE","FEMALE","ALCOHOL CONSUMING","CHEST PAIN","SHORTNESS OF BREATH","COUGHING","PEER PRESSURE","CHRONIC DISEASE","SWALLOWING DIFFICULTY","YELLOW FINGERS","ANXIETY","FATIGUE","ALLERGY","WHEEZING","LUNG CANCER"]]
data.head()
# Out:
#    AGE  MALE  FEMALE  ALCOHOL CONSUMING  CHEST PAIN  SHORTNESS OF BREATH  \
# 0   69     1       0                  2           2                    2
# 1   74     1       0                  1           2                    2
# 2   59     0       1                  1           2                    2
# 3   63     1       0                  2           2                    1
# 4   63     0       1                  1           1                    2
#
#    COUGHING  PEER PRESSURE  CHRONIC DISEASE  SWALLOWING DIFFICULTY  \
# 0         2              1                1                      2
# 1         1              1                2                      2
# 2         2              2                1                      1
# 3         1              1                1                      2
# 4         2              1                1                      1
#
#    YELLOW FINGERS  ANXIETY  FATIGUE  ALLERGY  WHEEZING  LUNG CANCER
# 0               2        2        2        1         2            1
# 1               1        1        2        2         1            1
# 2               1        1        2        1         2            0
# 3               2        2        1        1         1            0
# 4               2        1        1        1         2            0

# %%
plt.subplots(figsize =(16, 12))

p=sns.heatmap(data.corr(), cmap = palette, square=True, cbar_kws=dict(shrink =.99),
            annot=True, vmin=-1, vmax=1, linewidths=0.1,linecolor='white',annot_kws=dict(fontsize =12))
p.axes.set_title("Pearson Correlation Of Features\n", fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##Preprocessing For Classification

# %%
x = data.drop("LUNG CANCER", axis = 1)
y = data["LUNG CANCER"]

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
x = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

print(f"Shape of training data : {x_train.shape}, {y_train.shape}")
print(f"Shape of testing data : {x_test.shape}, {y_test.shape}")
# Out:
# Shape of training data : (220, 15), (220,)
# Shape of testing data : (56, 15), (56,)

# %% [markdown]
# ####Logistic Regression Model

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

lr = LogisticRegression()
lr.fit(x_train, y_train)

# Make predictions
lr_pred = lr.predict(x_test)

# Calculate predicted probabilities for the positive class
lr_pred_prob = lr.predict_proba(x_test)[:, 1]

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, lr_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC curve (area = {auc(fpr, tpr):.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Random guess line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - Logistic Regression')
plt.legend()
plt.show()


lr_conf = confusion_matrix(y_test, lr_pred)
lr_report = classification_report(y_test, lr_pred)
lr_acc = round(accuracy_score(y_test, lr_pred) * 100, ndigits=2)

print(f"Confusion Matrix : \n\n{lr_conf}")
print(f"\nClassification Report : \n\n{lr_report}")
print(f"\nThe Accuracy of Logistic Regression is {lr_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 5  7]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.42      0.59        12
#            1       0.86      1.00      0.93        44
#
#     accuracy                           0.88        56
#    macro avg       0.93      0.71      0.76        56
# weighted avg       0.89      0.88      0.85        56
#
#
# The Accuracy of Logistic Regression is 87.5 %

# %% [markdown]
# ##Gaussian Naive Bayes Model

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(x_train, y_train)
gnb_pred = gnb.predict(x_test)
gnb_conf = confusion_matrix(y_test, gnb_pred)
gnb_report = classification_report(y_test, gnb_pred)
gnb_acc = round(accuracy_score(y_test, gnb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{gnb_conf}")
print(f"\nClassification Report : \n\n{gnb_report}")
print(f"\nThe Accuracy of Gaussian Naive Bayes is {gnb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 8  4]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        12
#            1       0.91      0.98      0.95        44
#
#     accuracy                           0.91        56
#    macro avg       0.90      0.82      0.85        56
# weighted avg       0.91      0.91      0.91        56
#
#
# The Accuracy of Gaussian Naive Bayes is 91.07 %

# %% [markdown]
# ##Support Vector Machine Model

# %%
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

svm = SVC(C=100, gamma=0.002)
svm.fit(x_train, y_train)

# Make predictions
svm_pred = svm.predict(x_test)

# Calculate predicted probabilities for the positive class
svm_pred_prob = svm.decision_function(x_test)  # For SVC, use decision_function instead of predict_proba

# Calculate ROC curve
fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_test, svm_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr_svm, tpr_svm, label=f'ROC curve (area = {auc(fpr_svm, tpr_svm):.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Random guess line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - Support Vector Machine')
plt.legend()
plt.show()

# Continue with the rest of your code
svm_conf = confusion_matrix(y_test, svm_pred)
svm_report = classification_report(y_test, svm_pred)
svm_acc = round(accuracy_score(y_test, svm_pred) * 100, ndigits=2)

print(f"Confusion Matrix : \n\n{svm_conf}")
print(f"\nClassification Report : \n\n{svm_report}")
print(f"\nThe Accuracy of Support Vector Machine is {svm_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 4  8]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        12
#            1       0.85      1.00      0.92        44
#
#     accuracy                           0.86        56
#    macro avg       0.92      0.67      0.71        56
# weighted avg       0.88      0.86      0.83        56
#
#
# The Accuracy of Support Vector Machine is 85.71 %

# %% [markdown]
# ##Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

rfg = RandomForestClassifier(n_estimators=100, random_state=42)
rfg.fit(x_train, y_train)

# Make predictions
rfg_pred = rfg.predict(x_test)

# Calculate predicted probabilities for the positive class
rfg_pred_prob = rfg.predict_proba(x_test)[:, 1]

# Calculate ROC curve
fpr_rfg, tpr_rfg, thresholds_rfg = roc_curve(y_test, rfg_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr_rfg, tpr_rfg, label=f'ROC curve (area = {auc(fpr_rfg, tpr_rfg):.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Random guess line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - Random Forest Classifier')
plt.legend()
plt.show()

# Continue with the rest of your code
rfg_conf = confusion_matrix(y_test, rfg_pred)
rfg_report = classification_report(y_test, rfg_pred)
rfg_acc = round(accuracy_score(y_test, rfg_pred) * 100, ndigits=2)

print(f"Confusion Matrix : \n\n{rfg_conf}")
print(f"\nClassification Report : \n\n{rfg_report}")
print(f"\nThe Accuracy of Random Forest Classifier is {rfg_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 4  8]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        12
#            1       0.85      1.00      0.92        44
#
#     accuracy                           0.86        56
#    macro avg       0.92      0.67      0.71        56
# weighted avg       0.88      0.86      0.83        56
#
#
# The Accuracy of Random Forest Classifier is 85.71 %

# %% [markdown]
# ##Gradient Boosting Model

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(use_label_encoder = False)
xgb.fit(x_train, y_train)
xgb_pred = xgb.predict(x_test)
xgb_conf = confusion_matrix(y_test, xgb_pred)
xgb_report = classification_report(y_test, xgb_pred)
xgb_acc = round(accuracy_score(y_test, xgb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{xgb_conf}")
print(f"\nClassification Report : \n\n{xgb_report}")
print(f"\nThe Accuracy of Extreme Gradient Boosting Classifier is {xgb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 6  6]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67        12
#            1       0.88      1.00      0.94        44
#
#     accuracy                           0.89        56
#    macro avg       0.94      0.75      0.80        56
# weighted avg       0.91      0.89      0.88        56
#
#
# The Accuracy of Extreme Gradient Boosting Classifier is 89.29 %

# %% [markdown]
# ##Neural Network Architecture

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

regularization_parameter = 0.003

neural_model = Sequential([tf.keras.layers.Dense(units=32, input_dim=(x_train.shape[-1]), activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=64, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=128, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dropout(0.3),
                    tf.keras.layers.Dense(units=16,activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=1, activation="sigmoid")
                    ])

print(neural_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                512
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_3 (Dense)             (None, 16)                2064
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 13025 (50.88 KB)
# Trainable params: 13025 (50.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get("accuracy") == 1.0):
            print("\nAccuracy is 100% so canceling training!")
            self.model.stop_training = True

callbacks = myCallback()


neural_model.compile(optimizer = Adam(learning_rate = 0.001),
                     loss = "binary_crossentropy",
                     metrics = ["accuracy"])

history = neural_model.fit(x_train, y_train,
                           epochs = 150,
                           verbose = 1,
                           batch_size = 64,
                           validation_data = (x_test, y_test),
                           callbacks = [callbacks])
# Out:
# Epoch 1/150
# 4/4 [==============================] - 4s 213ms/step - loss: 4.4134 - accuracy: 0.8364 - val_loss: 4.3202 - val_accuracy: 0.7857
# Epoch 2/150
# 4/4 [==============================] - 0s 35ms/step - loss: 4.2246 - accuracy: 0.8864 - val_loss: 4.1667 - val_accuracy: 0.7857
# Epoch 3/150
# 4/4 [==============================] - 0s 20ms/step - loss: 4.0369 - accuracy: 0.8818 - val_loss: 4.0302 - val_accuracy: 0.7857
# Epoch 4/150
# 4/4 [==============================] - 0s 20ms/step - loss: 3.8756 - accuracy: 0.8818 - val_loss: 3.9097 - val_accuracy: 0.7857
# Epoch 5/150
# 4/4 [==============================] - 0s 20ms/step - loss: 3.7261 - accuracy: 0.8818 - val_loss: 3.8015 - val_accuracy: 0.7857
# Epoch 6/150
# 4/4 [==============================] - 0s 32ms/step - loss: 3.5967 - accuracy: 0.8818 - val_loss: 3.6889 - val_accuracy: 0.7857
# Epoch 7/150
# 4/4 [==============================] - 0s 31ms/step - loss: 3.4795 - accuracy: 0.8818 - val_loss: 3.5724 - val_accuracy: 0.7857
# Epoch 8/150
# 4/4 [==============================] - 0s 27ms/step - loss: 3.3486 - accuracy: 0.8818 - val_loss: 3.4488 - val_accuracy: 0.7857
# Epoch 9/150
# 4/4 [==============================] - 0s 23ms/step - loss: 3.2326 - accuracy: 0.8818 - val_loss: 3.3210 - val_accuracy: 0.7857
# Epoch 10/150
# 4/4 [==============================] - 0s 27ms/step - loss: 3.1108 - accuracy: 0.8818 - val_loss: 3.1958 - val_accuracy: 0.7857
# Epoch 11/150
# 4/4 [==============================] - 0s 28ms/step - loss: 3.0078 - accuracy: 0.8818 - val_loss: 3.0739 - val_accuracy: 0.7857
# Epoch 12/150
# 4/4 [==============================] - 0s 40ms/step - loss: 2.8942 - accuracy: 0.8818 - val_loss: 2.9615 - val_accuracy: 0.7857
# Epoch 13/150
# 4/4 [==============================] - 0s 50ms/step - loss: 2.7897 - accuracy: 0.8818 - val_loss: 2.8530 - val_accuracy: 0.7857
# Epoch 14/150
# 4/4 [==============================] - 0s 44ms/step - loss: 2.6841 - accuracy: 0.8818 - val_loss: 2.7457 - val_accuracy: 0.7857
# Epoch 15/150
# 4/4 [==============================] - 0s 45ms/step - loss: 2.5886 - accuracy: 0.8818 - val_loss: 2.6429 - val_accuracy: 0.7857
# Epoch 16/150
# 4/4 [==============================] - 0s 59ms/step - loss: 2.4844 - accuracy: 0.8818 - val_loss: 2.5410 - val_accuracy: 0.7857
# Epoch 17/150
# 4/4 [==============================] - 0s 38ms/step - loss: 2.3840 - accuracy: 0.8818 - val_loss: 2.4432 - val_accuracy: 0.7857
# Epoch 18/150
# 4/4 [==============================] - 0s 94ms/step - loss: 2.2903 - accuracy: 0.8818 - val_loss: 2.3482 - val_accuracy: 0.7857
# Epoch 19/150
# 4/4 [==============================] - 0s 90ms/step - loss: 2.2029 - accuracy: 0.8818 - val_loss: 2.2559 - val_accuracy: 0.7857
# Epoch 20/150
# 4/4 [==============================] - 0s 97ms/step - loss: 2.1138 - accuracy: 0.8909 - val_loss: 2.1647 - val_accuracy: 0.7857
# Epoch 21/150
# 4/4 [==============================] - 0s 81ms/step - loss: 2.0241 - accuracy: 0.8818 - val_loss: 2.0767 - val_accuracy: 0.7857
# Epoch 22/150
# 4/4 [==============================] - 0s 44ms/step - loss: 1.9431 - accuracy: 0.8864 - val_loss: 1.9896 - val_accuracy: 0.7857
# Epoch 23/150
# 4/4 [==============================] - 0s 22ms/step - loss: 1.8581 - accuracy: 0.8909 - val_loss: 1.9068 - val_accuracy: 0.8036
# Epoch 24/150
# 4/4 [==============================] - 0s 22ms/step - loss: 1.7848 - accuracy: 0.9045 - val_loss: 1.8266 - val_accuracy: 0.8036
# Epoch 25/150
# 4/4 [==============================] - 0s 18ms/step - loss: 1.7140 - accuracy: 0.9136 - val_loss: 1.7508 - val_accuracy: 0.8036
# Epoch 26/150
# 4/4 [==============================] - 0s 26ms/step - loss: 1.6337 - accuracy: 0.9045 - val_loss: 1.6807 - val_accuracy: 0.8036
# Epoch 27/150
# 4/4 [==============================] - 0s 18ms/step - loss: 1.5677 - accuracy: 0.9045 - val_loss: 1.6120 - val_accuracy: 0.8036
# Epoch 28/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.4968 - accuracy: 0.9091 - val_loss: 1.5426 - val_accuracy: 0.8036
# Epoch 29/150
# 4/4 [==============================] - 0s 24ms/step - loss: 1.4319 - accuracy: 0.9182 - val_loss: 1.4747 - val_accuracy: 0.8036
# Epoch 30/150
# 4/4 [==============================] - 0s 24ms/step - loss: 1.3666 - accuracy: 0.9182 - val_loss: 1.4117 - val_accuracy: 0.8036
# Epoch 31/150
# 4/4 [==============================] - 0s 23ms/step - loss: 1.3089 - accuracy: 0.9136 - val_loss: 1.3526 - val_accuracy: 0.8036
# Epoch 32/150
# 4/4 [==============================] - 0s 25ms/step - loss: 1.2499 - accuracy: 0.9273 - val_loss: 1.2948 - val_accuracy: 0.8214
# Epoch 33/150
# 4/4 [==============================] - 0s 23ms/step - loss: 1.1957 - accuracy: 0.9136 - val_loss: 1.2396 - val_accuracy: 0.8214
# Epoch 34/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1447 - accuracy: 0.9136 - val_loss: 1.1887 - val_accuracy: 0.8214
# Epoch 35/150
# 4/4 [==============================] - 0s 23ms/step - loss: 1.0938 - accuracy: 0.9318 - val_loss: 1.1409 - val_accuracy: 0.8214
# Epoch 36/150
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0452 - accuracy: 0.9182 - val_loss: 1.0969 - val_accuracy: 0.8214
# Epoch 37/150
# 4/4 [==============================] - 0s 24ms/step - loss: 0.9950 - accuracy: 0.9182 - val_loss: 1.0535 - val_accuracy: 0.8214
# Epoch 38/150
# 4/4 [==============================] - 0s 25ms/step - loss: 0.9618 - accuracy: 0.9273 - val_loss: 1.0160 - val_accuracy: 0.8214
# Epoch 39/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.9216 - accuracy: 0.9273 - val_loss: 0.9801 - val_accuracy: 0.8214
# Epoch 40/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.8883 - accuracy: 0.9273 - val_loss: 0.9425 - val_accuracy: 0.8214
# Epoch 41/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.8553 - accuracy: 0.9273 - val_loss: 0.9078 - val_accuracy: 0.8214
# Epoch 42/150
# 4/4 [==============================] - 0s 25ms/step - loss: 0.8208 - accuracy: 0.9273 - val_loss: 0.8800 - val_accuracy: 0.8214
# Epoch 43/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7950 - accuracy: 0.9227 - val_loss: 0.8547 - val_accuracy: 0.8214
# Epoch 44/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7705 - accuracy: 0.9273 - val_loss: 0.8303 - val_accuracy: 0.8393
# Epoch 45/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7489 - accuracy: 0.9318 - val_loss: 0.8081 - val_accuracy: 0.8393
# Epoch 46/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.7270 - accuracy: 0.9318 - val_loss: 0.7879 - val_accuracy: 0.8393
# Epoch 47/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7036 - accuracy: 0.9455 - val_loss: 0.7693 - val_accuracy: 0.8393
# Epoch 48/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6871 - accuracy: 0.9273 - val_loss: 0.7506 - val_accuracy: 0.8393
# Epoch 49/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6711 - accuracy: 0.9409 - val_loss: 0.7332 - val_accuracy: 0.8393
# Epoch 50/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6536 - accuracy: 0.9409 - val_loss: 0.7170 - val_accuracy: 0.8393
# Epoch 51/150
# 4/4 [==============================] - 0s 27ms/step - loss: 0.6397 - accuracy: 0.9318 - val_loss: 0.7046 - val_accuracy: 0.8393
# Epoch 52/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.6225 - accuracy: 0.9364 - val_loss: 0.6911 - val_accuracy: 0.8393
# Epoch 53/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6142 - accuracy: 0.9364 - val_loss: 0.6789 - val_accuracy: 0.8393
# Epoch 54/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6011 - accuracy: 0.9364 - val_loss: 0.6659 - val_accuracy: 0.8393
# Epoch 55/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5826 - accuracy: 0.9364 - val_loss: 0.6528 - val_accuracy: 0.8393
# Epoch 56/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5794 - accuracy: 0.9273 - val_loss: 0.6397 - val_accuracy: 0.8393
# Epoch 57/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5650 - accuracy: 0.9455 - val_loss: 0.6280 - val_accuracy: 0.8393
# Epoch 58/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5559 - accuracy: 0.9364 - val_loss: 0.6168 - val_accuracy: 0.8393
# Epoch 59/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5440 - accuracy: 0.9500 - val_loss: 0.6056 - val_accuracy: 0.8571
# Epoch 60/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5352 - accuracy: 0.9500 - val_loss: 0.5951 - val_accuracy: 0.8750
# Epoch 61/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5261 - accuracy: 0.9455 - val_loss: 0.5880 - val_accuracy: 0.8750
# Epoch 62/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5174 - accuracy: 0.9500 - val_loss: 0.5838 - val_accuracy: 0.8393
# Epoch 63/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5054 - accuracy: 0.9455 - val_loss: 0.5755 - val_accuracy: 0.8571
# Epoch 64/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4982 - accuracy: 0.9409 - val_loss: 0.5661 - val_accuracy: 0.8750
# Epoch 65/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4962 - accuracy: 0.9364 - val_loss: 0.5600 - val_accuracy: 0.8750
# Epoch 66/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4859 - accuracy: 0.9455 - val_loss: 0.5508 - val_accuracy: 0.8750
# Epoch 67/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4807 - accuracy: 0.9455 - val_loss: 0.5441 - val_accuracy: 0.8750
# Epoch 68/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4785 - accuracy: 0.9500 - val_loss: 0.5388 - val_accuracy: 0.8750
# Epoch 69/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4689 - accuracy: 0.9500 - val_loss: 0.5351 - val_accuracy: 0.8750
# Epoch 70/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4585 - accuracy: 0.9500 - val_loss: 0.5323 - val_accuracy: 0.8750
# Epoch 71/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4616 - accuracy: 0.9409 - val_loss: 0.5285 - val_accuracy: 0.8750
# Epoch 72/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4498 - accuracy: 0.9455 - val_loss: 0.5254 - val_accuracy: 0.8750
# Epoch 73/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4530 - accuracy: 0.9364 - val_loss: 0.5191 - val_accuracy: 0.8750
# Epoch 74/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4431 - accuracy: 0.9500 - val_loss: 0.5115 - val_accuracy: 0.8750
# Epoch 75/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4419 - accuracy: 0.9545 - val_loss: 0.5075 - val_accuracy: 0.8750
# Epoch 76/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4312 - accuracy: 0.9455 - val_loss: 0.5039 - val_accuracy: 0.8750
# Epoch 77/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4290 - accuracy: 0.9455 - val_loss: 0.5001 - val_accuracy: 0.8750
# Epoch 78/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4222 - accuracy: 0.9455 - val_loss: 0.4961 - val_accuracy: 0.8750
# Epoch 79/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4183 - accuracy: 0.9455 - val_loss: 0.4919 - val_accuracy: 0.8750
# Epoch 80/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4167 - accuracy: 0.9500 - val_loss: 0.4883 - val_accuracy: 0.8750
# Epoch 81/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4143 - accuracy: 0.9500 - val_loss: 0.4853 - val_accuracy: 0.8750
# Epoch 82/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4038 - accuracy: 0.9455 - val_loss: 0.4828 - val_accuracy: 0.8750
# Epoch 83/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4031 - accuracy: 0.9500 - val_loss: 0.4770 - val_accuracy: 0.8750
# Epoch 84/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4015 - accuracy: 0.9455 - val_loss: 0.4697 - val_accuracy: 0.8929
# Epoch 85/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3991 - accuracy: 0.9455 - val_loss: 0.4663 - val_accuracy: 0.8929
# Epoch 86/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3969 - accuracy: 0.9500 - val_loss: 0.4644 - val_accuracy: 0.8929
# Epoch 87/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3921 - accuracy: 0.9500 - val_loss: 0.4624 - val_accuracy: 0.8929
# Epoch 88/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3882 - accuracy: 0.9455 - val_loss: 0.4608 - val_accuracy: 0.8929
# Epoch 89/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3779 - accuracy: 0.9545 - val_loss: 0.4569 - val_accuracy: 0.8929
# Epoch 90/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3853 - accuracy: 0.9455 - val_loss: 0.4552 - val_accuracy: 0.8929
# Epoch 91/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3785 - accuracy: 0.9500 - val_loss: 0.4520 - val_accuracy: 0.8929
# Epoch 92/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3777 - accuracy: 0.9500 - val_loss: 0.4485 - val_accuracy: 0.8929
# Epoch 93/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3735 - accuracy: 0.9545 - val_loss: 0.4450 - val_accuracy: 0.9286
# Epoch 94/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3712 - accuracy: 0.9500 - val_loss: 0.4414 - val_accuracy: 0.9286
# Epoch 95/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3626 - accuracy: 0.9500 - val_loss: 0.4381 - val_accuracy: 0.9286
# Epoch 96/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3634 - accuracy: 0.9500 - val_loss: 0.4362 - val_accuracy: 0.9286
# Epoch 97/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3663 - accuracy: 0.9545 - val_loss: 0.4356 - val_accuracy: 0.9464
# Epoch 98/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3640 - accuracy: 0.9455 - val_loss: 0.4334 - val_accuracy: 0.9464
# Epoch 99/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3555 - accuracy: 0.9545 - val_loss: 0.4321 - val_accuracy: 0.9107
# Epoch 100/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3585 - accuracy: 0.9455 - val_loss: 0.4312 - val_accuracy: 0.8929
# Epoch 101/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3523 - accuracy: 0.9500 - val_loss: 0.4280 - val_accuracy: 0.9107
# Epoch 102/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3478 - accuracy: 0.9455 - val_loss: 0.4256 - val_accuracy: 0.9107
# Epoch 103/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3494 - accuracy: 0.9545 - val_loss: 0.4245 - val_accuracy: 0.8929
# Epoch 104/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3475 - accuracy: 0.9500 - val_loss: 0.4210 - val_accuracy: 0.9286
# Epoch 105/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3477 - accuracy: 0.9500 - val_loss: 0.4183 - val_accuracy: 0.9286
# Epoch 106/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3445 - accuracy: 0.9545 - val_loss: 0.4146 - val_accuracy: 0.9464
# Epoch 107/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3446 - accuracy: 0.9455 - val_loss: 0.4101 - val_accuracy: 0.9286
# Epoch 108/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3394 - accuracy: 0.9545 - val_loss: 0.4078 - val_accuracy: 0.9286
# Epoch 109/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3368 - accuracy: 0.9500 - val_loss: 0.4065 - val_accuracy: 0.9286
# Epoch 110/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3360 - accuracy: 0.9545 - val_loss: 0.4076 - val_accuracy: 0.8929
# Epoch 111/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3313 - accuracy: 0.9591 - val_loss: 0.4068 - val_accuracy: 0.8929
# Epoch 112/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3315 - accuracy: 0.9500 - val_loss: 0.4033 - val_accuracy: 0.8929
# Epoch 113/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3267 - accuracy: 0.9591 - val_loss: 0.4011 - val_accuracy: 0.9107
# Epoch 114/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3223 - accuracy: 0.9545 - val_loss: 0.3987 - val_accuracy: 0.9286
# Epoch 115/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3174 - accuracy: 0.9500 - val_loss: 0.3969 - val_accuracy: 0.9286
# Epoch 116/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3200 - accuracy: 0.9545 - val_loss: 0.3967 - val_accuracy: 0.8929
# Epoch 117/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3211 - accuracy: 0.9545 - val_loss: 0.3955 - val_accuracy: 0.8929
# Epoch 118/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3185 - accuracy: 0.9500 - val_loss: 0.3948 - val_accuracy: 0.8929
# Epoch 119/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3185 - accuracy: 0.9591 - val_loss: 0.3940 - val_accuracy: 0.8929
# Epoch 120/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3092 - accuracy: 0.9500 - val_loss: 0.3913 - val_accuracy: 0.8929
# Epoch 121/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3180 - accuracy: 0.9591 - val_loss: 0.3892 - val_accuracy: 0.8929
# Epoch 122/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3106 - accuracy: 0.9591 - val_loss: 0.3852 - val_accuracy: 0.9643
# Epoch 123/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3091 - accuracy: 0.9591 - val_loss: 0.3835 - val_accuracy: 0.9464
# Epoch 124/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3109 - accuracy: 0.9545 - val_loss: 0.3809 - val_accuracy: 0.9286
# Epoch 125/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3035 - accuracy: 0.9545 - val_loss: 0.3813 - val_accuracy: 0.9107
# Epoch 126/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3003 - accuracy: 0.9591 - val_loss: 0.3789 - val_accuracy: 0.9464
# Epoch 127/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3049 - accuracy: 0.9545 - val_loss: 0.3774 - val_accuracy: 0.9286
# Epoch 128/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3001 - accuracy: 0.9591 - val_loss: 0.3748 - val_accuracy: 0.9286
# Epoch 129/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2926 - accuracy: 0.9636 - val_loss: 0.3715 - val_accuracy: 0.9286
# Epoch 130/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2935 - accuracy: 0.9545 - val_loss: 0.3701 - val_accuracy: 0.9286
# Epoch 131/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2927 - accuracy: 0.9500 - val_loss: 0.3698 - val_accuracy: 0.9286
# Epoch 132/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2937 - accuracy: 0.9545 - val_loss: 0.3672 - val_accuracy: 0.9286
# Epoch 133/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3015 - accuracy: 0.9500 - val_loss: 0.3679 - val_accuracy: 0.9286
# Epoch 134/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2901 - accuracy: 0.9500 - val_loss: 0.3683 - val_accuracy: 0.9286
# Epoch 135/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2903 - accuracy: 0.9591 - val_loss: 0.3667 - val_accuracy: 0.9286
# Epoch 136/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2873 - accuracy: 0.9500 - val_loss: 0.3663 - val_accuracy: 0.9286
# Epoch 137/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2907 - accuracy: 0.9545 - val_loss: 0.3656 - val_accuracy: 0.9464
# Epoch 138/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2803 - accuracy: 0.9636 - val_loss: 0.3636 - val_accuracy: 0.9286
# Epoch 139/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2935 - accuracy: 0.9545 - val_loss: 0.3621 - val_accuracy: 0.9286
# Epoch 140/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2795 - accuracy: 0.9591 - val_loss: 0.3613 - val_accuracy: 0.9286
# Epoch 141/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2807 - accuracy: 0.9545 - val_loss: 0.3583 - val_accuracy: 0.9286
# Epoch 142/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2883 - accuracy: 0.9455 - val_loss: 0.3555 - val_accuracy: 0.9107
# Epoch 143/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2815 - accuracy: 0.9545 - val_loss: 0.3551 - val_accuracy: 0.9286
# Epoch 144/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2791 - accuracy: 0.9636 - val_loss: 0.3562 - val_accuracy: 0.9286
# Epoch 145/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2756 - accuracy: 0.9591 - val_loss: 0.3591 - val_accuracy: 0.8929
# Epoch 146/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2753 - accuracy: 0.9636 - val_loss: 0.3615 - val_accuracy: 0.8929
# Epoch 147/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2827 - accuracy: 0.9591 - val_loss: 0.3606 - val_accuracy: 0.8929
# Epoch 148/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2765 - accuracy: 0.9545 - val_loss: 0.3583 - val_accuracy: 0.8929
# Epoch 149/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2743 - accuracy: 0.9591 - val_loss: 0.3566 - val_accuracy: 0.8929
# Epoch 150/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2773 - accuracy: 0.9636 - val_loss: 0.3561 - val_accuracy: 0.8929

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(len(acc)) # number of epochs

plt.figure(figsize=(20, 12))
plt.subplot(2,1,1)
plt.plot(epochs, acc, "yellow", label= "Training Accuracy")
plt.plot(epochs, val_acc, "black", label= "Validation Accuracy")
plt.title("Training and validation accuracy")
plt.legend()

plt.subplot(2,1,2)
plt.plot(epochs, loss, "yellow", label= "Training Loss")
plt.plot(epochs, val_loss, "black", label= "Validation Loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()
